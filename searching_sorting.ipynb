# %%
# Linear Searching
# Binary

# Sleep Sort
# Monkey Sort

#######  Imp Sorting Algorithm
# Bubble Sort
# Selection
# Merge Sort
# Quick Sort
# Insertion Sort

# %% [markdown]
# ### Linear Search

# %%
# Linear Search

# Brute Force

def linear_search(arr,item):

  for i in range(len(arr)):

    if arr[i] == item:
      return i

  return -1

# %%
arr = [12,34,56,1,67,100,47,99]

linear_search(arr,121)
# Out:
# -1

# %%
# Time Complexity is O(N)
# No sorting required

# %% [markdown]
# ### Binary Search

# %%
# Binary Search

# Sorted Array 

def binary_search(arr, low, high, item):

  #print("low = ",low,"high = ",high,end=' ')

  if low <= high:
    # search

    mid = (low + high)//2

    #print("mid value is",arr[mid])

    if arr[mid] == item:
      return mid
    elif arr[mid] > item:
      return binary_search(arr, low, mid-1,item)
    else:
      return binary_search(arr,mid+1,high,item)
  else:
    return -1

# %%
arr = [12,24,35,46,57,68,80,99,100]
print(binary_search(arr,0,len(arr)-1,-5))
# Out:
# -1

# %% [markdown]
# ### How to detect wheather given array is sorted or not?

# %%
# Sorting

def is_sorted(arr):

  sorted = True

  for i in range(len(arr) - 1):
    if arr[i]>arr[i+1]:
      sorted = False
  
  return sorted

# %%
arr = [1,2,3,4,8,6]
is_sorted(arr)
# Out:
# False

# %% [markdown]
# ### Monkey sort

# %%
# Monkey sort

import random
a=[1,2,3,4]
random.shuffle(a)
a
# Out:
# [2, 1, 3, 4]

# %%
import time
def monkey_sort(arr):

  while not is_sorted(arr):
    time.sleep(1)
    random.shuffle(arr)
    print(arr)
  print(arr)

# %%
a = [12,24,11,56,34,20]
monkey_sort(a)
# Out:
# [24, 20, 11, 56, 12, 34]
# [11, 34, 12, 56, 20, 24]
# [20, 11, 24, 12, 34, 56]
# [24, 20, 34, 56, 11, 12]
# [56, 34, 12, 20, 11, 24]
# [34, 12, 11, 20, 56, 24]
# [56, 34, 20, 12, 11, 24]
# [11, 20, 34, 56, 24, 12]
# [24, 12, 11, 34, 56, 20]
# [20, 56, 11, 24, 34, 12]
# [56, 12, 24, 20, 11, 34]
# [56, 20, 24, 34, 11, 12]
# [56, 20, 24, 11, 34, 12]
# [56, 12, 24, 20, 34, 11]
# [11, 12, 20, 24, 34, 56]
# [11, 12, 20, 24, 34, 56]

# %%
12 24 45 5 16

# %%
5 12 16 24 45

# %% [markdown]
# ### Sleep Sort

# %%
import time

def sleep_sort(array):
    sorted_array = []

    for num in array:
        time.sleep(num)
        sorted_array.append(num)

    return sorted_array

# %%
# Example usage:
array = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
sorted_array = sleep_sort(array)
print(sorted_array)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]

# %% [markdown]
# ### Bubble Sort

# %%
def bubble_sort(arr):

  for i in range(len(arr) - 1):
    flag = 0
    for j in range(len(arr) - 1 - i):
      if arr[j] > arr[j+1]:
        arr[j],arr[j+1] = arr[j+1],arr[j]
        flag =1

    if flag == 0:
      break
  
  return arr

# %%
arr = [23,12,34,11,100,56,78]
bubble_sort(arr)
# Out:
# [11, 12, 23, 34, 56, 78, 100]

# %%
#######  Imp Sorting Algorithm
# Bubble Sort
# Selection
# Merge Sort
# Quick Sort
# Insertion Sort

# %% [markdown]
# ### Selection Short

# %%
def selection_sort(arr):

  for i in range(len(arr) - 1):

    min = i

    for j in range(i+1,len(arr)):
      if arr[j] < arr[min]:
        min = j
    
    arr[i],arr[min] = arr[min],arr[i]

  return arr

# %%
arr = [23,12,34,11,100,56,78]
selection_sort(arr)
# Out:
# 1 pass Current min is 23
# Current item under observation 12
# Current item is less than min
# Now the min has become 12
# Current item under observation 34
# Current item under observation 11
# Current item is less than min
# Now the min has become 11
# Current item under observation 100
# Current item under observation 56
# Current item under observation 78
# [11, 12, 34, 23, 100, 56, 78]
# **************************************************
# 2 pass Current min is 12
# Current item under observation 34
# Current item under observation 23
# Current item under observation 100
# Current item under observation 56
# Current item under observation 78
# [11, 12, 34, 23, 100, 56, 78]
# **************************************************
# 3 pass Current min is 34
# Current item under observation 23
# Current item is less than min
# Now the min has become 23
# Current item under observation 100
# Current item under observation 56
# Current item under observation 78
# ...

# %%
L = []

import random

for i in range(10000):
  L.append(random.randint(1,10000))

# %%
L
# Out:
# [4948,
#  3133,
#  1733,
#  1996,
#  7389,
#  4607,
#  4317,
#  2873,
#  396,
#  7054,
#  7694,
#  4432,
#  1226,
#  4997,
#  2101,
#  7072,
#  7172,
#  7389,
#  256,
#  6665,
#  7910,
#  6776,
#  1147,
#  5306,
#  5043,
#  4565,
#  8591,
#  5641,
#  2067,
#  6020,
#  2382,
#  2520,
#  858,
#  583,
#  7854,
#  126,
#  3549,
#  5732,
#  6424,
#  7987,
#  8767,
#  9839,
#  6445,
#  8991,
#  8702,
#  895,
#  7964,
#  3362,
#  5982,
#  5733,
#  4333,
#  1569,
#  1968,
#  7369,
#  6225,
#  8371,
#  3524,
#  844,
#  778,
#  6624,
#  5402,
#  8841,
#  4184,
#  7428,
#  4423,
#  7306,
#  8414,
#  9968,
#  8981,
#  7495,
#  2490,
#  6242,
#  1102,
#  2479,
#  4791,
#  9911,
#  46,
#  5997,
#  3520,
#  6889,
#  3401,
#  4984,
#  7557,
#  1418,
#  6350,
#  5711,
#  5301,
#  4310,
#  4529,
#  817,
#  18,
#  6664,
#  4629,
#  7313,
#  3607,
#  6550,
#  4381,
#  8837,
#  474,
#  1317,
#  7025,
#  4896,
#  427,
#  1134,
#  1802,
#  5520,
#  2598,
#  8699,
#  1304,
#  5800,
#  1399,
#  3350,
# ...

# %%
len(L)
# Out:
# 10000

# %%
L1 = L[:]
# cloning

# %%
L1
# Out:
# [4948,
#  3133,
#  1733,
#  1996,
#  7389,
#  4607,
#  4317,
#  2873,
#  396,
#  7054,
#  7694,
#  4432,
#  1226,
#  4997,
#  2101,
#  7072,
#  7172,
#  7389,
#  256,
#  6665,
#  7910,
#  6776,
#  1147,
#  5306,
#  5043,
#  4565,
#  8591,
#  5641,
#  2067,
#  6020,
#  2382,
#  2520,
#  858,
#  583,
#  7854,
#  126,
#  3549,
#  5732,
#  6424,
#  7987,
#  8767,
#  9839,
#  6445,
#  8991,
#  8702,
#  895,
#  7964,
#  3362,
#  5982,
#  5733,
#  4333,
#  1569,
#  1968,
#  7369,
#  6225,
#  8371,
#  3524,
#  844,
#  778,
#  6624,
#  5402,
#  8841,
#  4184,
#  7428,
#  4423,
#  7306,
#  8414,
#  9968,
#  8981,
#  7495,
#  2490,
#  6242,
#  1102,
#  2479,
#  4791,
#  9911,
#  46,
#  5997,
#  3520,
#  6889,
#  3401,
#  4984,
#  7557,
#  1418,
#  6350,
#  5711,
#  5301,
#  4310,
#  4529,
#  817,
#  18,
#  6664,
#  4629,
#  7313,
#  3607,
#  6550,
#  4381,
#  8837,
#  474,
#  1317,
#  7025,
#  4896,
#  427,
#  1134,
#  1802,
#  5520,
#  2598,
#  8699,
#  1304,
#  5800,
#  1399,
#  3350,
# ...

# %%
import time

start = time.time()
bubble_sort(L)
print("Time taken",time.time() - start,"secs")
# Out:
# Time taken 0.0 secs

# %%
start = time.time()
selection_sort(L1)
print("Time taken",time.time() - start,"secs")

# Not Adaptive
# Out:
# Time taken 4.384990453720093 secs

# %% [markdown]
# ### Merge Sort

# %%
def merge_arrays(arr1, arr2, arr):
    i = 0
    j = 0
    k = 0

    # new_arr = []

    while i < len(arr1) and j < len(arr2):
        if arr1[i] < arr2[j]:
            # new_arr.append(arr1[i])
            arr[k] = arr1[i]
            i += 1
        else:
            # new_arr.append(arr2[j])
            arr[k] = arr2[j]
            j += 1
        k += 1

    # this below will append the array of i & j if remaining
    while i < len(arr1):
        # new_arr.append(arr1[i])
        arr[k] = arr1[i]
        i += 1
        k += 1

    while j < len(arr2):
        # new_arr.append(arr2[j])
        arr[k] = arr2[j]
        j += 1
        k += 1

    # return new_arr  # Uncomment this line if you want to return a new array

# %%
# arr1 = [1, 2, 6, 7, 8, 12, 11, 10]
# arr2 = [2, 3, 5]

# # Sort arr1 and arr2
# arr1.sort()
# arr2.sort()
# # this sort() function will make this above just like this below
# # arr1 = [1, 2, 6, 7, 8, 10, 11, 12]
# # arr2 = [2, 3, 5]

# # Now, call merge_arrays with the sorted arrays
# result = merge_arrays(arr1, arr2)
# print(result)

# %%
# arr1 = [1,2,6,7,8,12,11,10]
# arr2 = [2,3,5]
# merge_arrays(arr1, arr2)

# %%
# merge_arrays(arr1,arr2)

# %%
# why this below code is not providing result is because the sorted results of the recursive calls to merge_sort(left) and merge_sort(right) are not 
# being stored back into the left and right variables. Instead, they are being discarded, and the function is not returning anything after the recursive
# calls.

# def merge_sort(arr):
#   if len(arr) <= 1:
#         return arr

#   mid = len(arr)//2 # calculate to splite the array in two  array

#   left = arr[:mid] # from 0 to mid left array
#   right = arr[mid:] # from mid to upto right array #

#   if len(left) == 1 and len(right) == 1: # single array is always sorted array so 
#     return merge_arrays(left,right) # passing to merge_arrays() function to recombine is sorted way
#   else:
#     merge_sort(left) # further pass to merge_sort to again split
#     merge_sort(right)

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    # left = merge_sort(arr[:mid])
    # right = merge_sort(arr[mid:])

    merge_sort(arr[:mid])
    merge_sort(arr[mid:])

    # return merge_arrays(left, right)

# %%
arr = [2,5,1,6,4,7,9,0]
merge_sort(arr)
print(arr)
# left = [2,5,1,6]
# right = [4,7,9,0]

# merge sort on left
# left1 = [2,5]
# right1 = [1,6]

# merge on left1
# left2 = [2]
# right2 = [5]
# Out:
# [2, 5, 1, 6, 4, 7, 9, 0]

# %%
# Merge Sort
# Quick Sort
# Insertion Sort

# %%
def quick_sort(arr):

  if len(arr) <= 1:
    return arr

  pivot = arr.pop()

  items_left = []
  items_right = []

  for item in arr:
    if item < pivot:
      items_left.append(item)
    else:
      items_right.append(item)

  return quick_sort(items_left) + [pivot] + quick_sort(items_right)

# %%
arr = [2,1,4,6,3,7,5]
quick_sort(arr)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
def quick_sort(arr,low,high):

  if len(arr) == 1:
    return arr

  if low < high:

    pi = partition(arr,low,high)

    quick_sort(arr,low,pi-1)
    quick_sort(arr,pi+1,high)

# %%
def partition(arr,low,high):

  i = low - 1
  pivot = arr[high]

  for j in range(low,high):

    if arr[j] <= pivot:
      i+=1
      arr[i],arr[j] = arr[j],arr[i]
  arr[i+1],arr[high] = arr[high],arr[i+1]

  return i+1

# %%
arr = [10, 7, 8, 9, 1, 5] 
n = len(arr) 
quick_sort(arr, 0, n-1)
print(arr)
# Out:
# [1, 5, 7, 8, 9, 10]
